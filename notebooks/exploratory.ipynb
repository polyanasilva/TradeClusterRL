# %% [markdown]
# # Exploratory analysis

# %%
import pandas as pd
from src.clustering.preprocessing import CandlePreprocessor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from src.clustering.preprocessing import CandlePreprocessor
#
# ModuleNotFoundError: No module named 'src'
